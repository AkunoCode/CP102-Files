# %% [markdown]
# # Pandas Self-Study
#
# Reference: https://www.youtube.com/watch?v=vmEHCJofslg&t=52s

# %% [markdown]
# ## Load data into Pandas

# %%
import pandas as pd

# %%
dataframe = pd.read_csv("pokemon.csv") # can also read_excel() or add delimiter for text files

print(dataframe.head(5)) #head method determines how many rows
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ## Reading Data in Pandas

# %%
# Read Headers
print(dataframe.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# Read specific column
dataframe["Name"][0:5] # Second bracket indicates range.

# Can also use multiple columns by list [["Name","Type 1","HP"]]
dataframe[["Name","Type 1","HP"]][0:5]
# Out:
#                     Name Type 1  HP
# 0              Bulbasaur  Grass  45
# 1                Ivysaur  Grass  60
# 2               Venusaur  Grass  80
# 3  VenusaurMega Venusaur  Grass  80
# 4             Charmander   Fire  39

# %%
# Read specific row
dataframe.iloc[1]
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %%
# Read specific row and column
dataframe.iloc[2,1] # [row,column]
# Out:
# 'Venusaur'

# %%
# Filtering
dataframe.loc[dataframe['Type 1'] == "Fire"].head(5)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 4       50     65           1      False    309
# 5       65     80           1      False    405
# 6       85    100           1      False    534
# 7       85    100           1      False    634
# 8      115    100           1      False    634

# %% [markdown]
# # Sorting/Describing Data

# %%
# Describe the datas mean etc...
dataframe.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
# Sorts by given value
dataframe.sort_values('Name').head(5)
# Out:
#        #                     Name   Type 1 Type 2  HP  Attack  Defense  \
# 510  460                Abomasnow    Grass    Ice  90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass    Ice  90     132      105
# 68    63                     Abra  Psychic    NaN  25      20       15
# 392  359                    Absol     Dark    NaN  65     130       60
# 393  359          AbsolMega Absol     Dark    NaN  65     150       60
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 510       92       85     60           4      False    494
# 511      132      105     30           4      False    594
# 68       105       55     90           1      False    310
# 392       75       60     75           3      False    465
# 393      115       60    115           3      False    565

# %%
# Sorts by given value 2
dataframe.sort_values(['Type 1','HP'], ascending=[1,0]).head(5) # Ascending Type 1 and Descending HP
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 520      116       56     95           4      False    515
# 698      135      105    100           5      False    550
# 231       40       95     85           2      False    500
# 232       40      105     75           2      False    600
# 678      100       60    145           5      False    495

# %% [markdown]
# ## Making Changes to the Data

# %%
dataframe.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# Create another column that calculates Total
dataframe['Total'] = dataframe['HP'] + dataframe['Attack'] + dataframe['Defense'] + dataframe['Sp. Atk'] + dataframe['Sp. Def'] + dataframe['Speed']

# %%
dataframe.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
# Drop other columns (Not show but won't overwrite)
dataframe.drop(columns=['Total']).head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# Specify [row, column 4:10] sum(axis=1) 1 means horizontal 0 will be vertical
# just like in range the last value is excluded so add 1: 9 + 1 = 10

dataframe['Total2'] = dataframe.iloc[:,4:10].sum(axis=1)

# %%
dataframe.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total  Total2
# 0       65     45           1      False    318     318
# 1       80     60           1      False    405     405
# 2      100     80           1      False    525     525
# 3      120     80           1      False    625     625
# 4       50     65           1      False    309     309

# %%
# Reorder the columns
cols = list(dataframe.columns.values)

# List slicing, single values or columns will be treated as str so enclose with []
# It only changes visually but not the actual data unless you assign it as dataframe
dataframe = dataframe[cols[0:4]+ [cols[-2]] + cols[4:12]]


dataframe.head(5)
# Out:
#    #                   Name Type 1  Type 2  Generation  Total  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison           1    318  45      49
# 1  2                Ivysaur  Grass  Poison           1    405  60      62
# 2  3               Venusaur  Grass  Poison           1    525  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison           1    625  80     100
# 4  4             Charmander   Fire     NaN           1    309  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       49       65       65     45           1
# 1       63       80       80     60           1
# 2       83      100      100     80           1
# 3      123      122      120     80           1
# 4       43       60       50     65           1

# %% [markdown]
# ## Saving Data (Into Desired Format)

# %%
# index=False removes the row indexes
dataframe.to_csv('modified_pokemon.csv', index=False)

# %%
dataframe.to_excel('modified_pokemon.xlsx')

# %%
dataframe.to_csv('modified_pokemon.txt', index=False, sep="\t")

# %% [markdown]
# ## Filtering Data

# %%
# Use the symbols instead of actual and/or
dataframe.loc[(dataframe['Type 1'] == 'Grass') & (dataframe['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2  Generation  Total   HP  \
# 0      1              Bulbasaur  Grass  Poison           1    318   45
# 1      2                Ivysaur  Grass  Poison           1    405   60
# 2      3               Venusaur  Grass  Poison           1    525   80
# 3      3  VenusaurMega Venusaur  Grass  Poison           1    625   80
# 48    43                 Oddish  Grass  Poison           1    320   45
# 49    44                  Gloom  Grass  Poison           1    395   60
# 50    45              Vileplume  Grass  Poison           1    490   75
# 75    69             Bellsprout  Grass  Poison           1    300   50
# 76    70             Weepinbell  Grass  Poison           1    390   65
# 77    71             Victreebel  Grass  Poison           1    490   80
# 344  315                Roselia  Grass  Poison           3    400   50
# 451  406                  Budew  Grass  Poison           4    280   40
# 452  407               Roserade  Grass  Poison           4    515   60
# 651  590                Foongus  Grass  Poison           5    294   69
# 652  591              Amoonguss  Grass  Poison           5    464  114
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0        49       49       65       65     45           1
# 1        62       63       80       80     60           1
# 2        82       83      100      100     80           1
# 3       100      123      122      120     80           1
# 48       50       55       75       65     30           1
# 49       65       70       85       75     40           1
# 50       80       85      110       90     50           1
# 75       75       35       70       30     40           1
# 76       90       50       85       45     55           1
# 77      105       65      100       70     70           1
# 344      60       45      100       80     65           3
# 451      30       35       50       70     55           4
# 452      70       65      125      105     90           4
# 651      55       45       55       55     15           5
# 652      85       70       85       80     30           5

# %%
#You can assign it as a new dataframe
df_new = dataframe.loc[(dataframe['Type 1'] == 'Grass') & (dataframe['Type 2'] == 'Poison') & (dataframe['HP'] >= 70)]

df_new.reset_index(drop=True, inplace=True) # resets the index and drop the old indeces
# inplace = True changes the value of the dataframe without needing to reassign it

df_new
# Out:
#      #                   Name Type 1  Type 2  Generation  Total   HP  Attack  \
# 0    3               Venusaur  Grass  Poison           1    525   80      82
# 1    3  VenusaurMega Venusaur  Grass  Poison           1    625   80     100
# 2   45              Vileplume  Grass  Poison           1    490   75      80
# 3   71             Victreebel  Grass  Poison           1    490   80     105
# 4  591              Amoonguss  Grass  Poison           5    464  114      85
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       83      100      100     80           1
# 1      123      122      120     80           1
# 2       85      110       90     50           1
# 3       65      100       70     70           1
# 4       70       85       80     30           5

# %%
# ~ means not similar to DS
dataframe.loc[~dataframe['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2  Generation  Total   HP  \
# 0      1            Bulbasaur    Grass  Poison           1    318   45
# 1      2              Ivysaur    Grass  Poison           1    405   60
# 2      3             Venusaur    Grass  Poison           1    525   80
# 4      4           Charmander     Fire     NaN           1    309   39
# 5      5           Charmeleon     Fire     NaN           1    405   58
# ..   ...                  ...      ...     ...         ...    ...  ...
# 794  718     Zygarde50% Forme   Dragon  Ground           6    600  108
# 795  719              Diancie     Rock   Fairy           6    600   50
# 797  720  HoopaHoopa Confined  Psychic   Ghost           6    600   80
# 798  720   HoopaHoopa Unbound  Psychic    Dark           6    680   80
# 799  721            Volcanion     Fire   Water           6    600   80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0        49       49       65       65     45           1
# 1        62       63       80       80     60           1
# 2        82       83      100      100     80           1
# 4        52       43       60       50     65           1
# 5        64       58       80       65     80           1
# ..      ...      ...      ...      ...    ...         ...
# 794     100      121       81       95     95           6
# 795     100      150      100      150     50           6
# 797     110       60      150      130     70           6
# 798     160       60      170      130     80           6
# 799     110      120      130       90     70           6
#
# [751 rows x 13 columns]

# %%
# Using RegEx
import re

dataframe.loc[dataframe['Name'].str.contains(r'^pi\w*', flags=re.IGNORECASE ,regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Generation  Total   HP  \
# 20    16               Pidgey    Normal    Flying           1    251   40
# 21    17            Pidgeotto    Normal    Flying           1    349   63
# 22    18              Pidgeot    Normal    Flying           1    479   83
# 23    18  PidgeotMega Pidgeot    Normal    Flying           1    579   83
# 30    25              Pikachu  Electric       NaN           1    320   35
# 136  127               Pinsir       Bug       NaN           1    500   65
# 137  127    PinsirMega Pinsir       Bug    Flying           1    600   65
# 186  172                Pichu  Electric       NaN           2    205   20
# 219  204               Pineco       Bug       NaN           2    290   50
# 239  221            Piloswine       Ice    Ground           2    450  100
# 438  393               Piplup     Water       NaN           4    314   53
# 558  499              Pignite      Fire  Fighting           5    418   90
# 578  519               Pidove    Normal    Flying           5    264   50
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 20       45       40       35       35     56           1
# 21       60       55       50       50     71           1
# 22       80       75       70       70    101           1
# 23       80       80      135       80    121           1
# 30       55       40       50       50     90           1
# 136     125      100       55       70     85           1
# 137     155      120       65       90    105           1
# 186      40       15       35       35     60           2
# 219      65       90       35       35     15           2
# 239     100       80       60       60     50           2
# 438      51       53       61       56     40           4
# 558      93       55       70       55     55           5
# 578      55       50       36       30     43           5

# %%
# Multiple Conditions
dataframe.loc[(dataframe['Name'].str.contains(r'^pi\w*',flags=re.IGNORECASE, regex=True)) & (~dataframe['Name'].str.contains('Mega'))]
# Name that starts with 'pi' and name that doesn't contain Mega
# Out:
#        #       Name    Type 1    Type 2  Generation  Total   HP  Attack  \
# 20    16     Pidgey    Normal    Flying           1    251   40      45
# 21    17  Pidgeotto    Normal    Flying           1    349   63      60
# 22    18    Pidgeot    Normal    Flying           1    479   83      80
# 30    25    Pikachu  Electric       NaN           1    320   35      55
# 136  127     Pinsir       Bug       NaN           1    500   65     125
# 186  172      Pichu  Electric       NaN           2    205   20      40
# 219  204     Pineco       Bug       NaN           2    290   50      65
# 239  221  Piloswine       Ice    Ground           2    450  100     100
# 438  393     Piplup     Water       NaN           4    314   53      51
# 558  499    Pignite      Fire  Fighting           5    418   90      93
# 578  519     Pidove    Normal    Flying           5    264   50      55
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation
# 20        40       35       35     56           1
# 21        55       50       50     71           1
# 22        75       70       70    101           1
# 30        40       50       50     90           1
# 136      100       55       70     85           1
# 186       15       35       35     60           2
# 219       90       35       35     15           2
# 239       80       60       60     50           2
# 438       53       61       56     40           4
# 558       55       70       55     55           5
# 578       50       36       30     43           5

# %% [markdown]
# ## Conditional Changes

# %%
# If type 1 == Fire then type 1 will be changed into flamer

#dataframe.loc[condition, column to change] = Value 
dataframe.loc[dataframe['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'

dataframe
# Out:
#        #                   Name   Type 1  Type 2  Generation  Total  HP  \
# 0      1              Bulbasaur    Grass  Poison           1    318  45
# 1      2                Ivysaur    Grass  Poison           1    405  60
# 2      3               Venusaur    Grass  Poison           1    525  80
# 3      3  VenusaurMega Venusaur    Grass  Poison           1    625  80
# 4      4             Charmander     Fire     NaN           1    309  39
# ..   ...                    ...      ...     ...         ...    ...  ..
# 795  719                Diancie     Rock   Fairy           6    600  50
# 796  719    DiancieMega Diancie     Rock   Fairy           6    700  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6    600  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6    680  80
# 799  721              Volcanion     Fire   Water           6    600  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation Legendary
# 0        49       49       65       65     45           1       NaN
# 1        62       63       80       80     60           1       NaN
# 2        82       83      100      100     80           1       NaN
# 3       100      123      122      120     80           1       NaN
# 4        52       43       60       50     65           1      True
# ..      ...      ...      ...      ...    ...         ...       ...
# 795     100      150      100      150     50           6       NaN
# 796     160      110      160      110    110           6       NaN
# 797     110       60      150      130     70           6       NaN
# 798     160       60      170      130     80           6       NaN
# 799     110      120      130       90     70           6      True
#
# [800 rows x 14 columns]

# %%
# If type 1 == Fire or type 2 == Water then Legendary column will be assigned as True
dataframe.loc[(dataframe['Type 1'] == 'Fire') | (dataframe['Type 2'] == 'Water'), 'Legendary'] = True

dataframe.loc[(dataframe['Type 1'] == 'Fire') | (dataframe['Type 2'] == 'Water')]
# Out:
#        #                       Name  Type 1  Type 2  Generation  Total  HP  \
# 4      4                 Charmander    Fire     NaN           1    309  39
# 5      5                 Charmeleon    Fire     NaN           1    405  58
# 6      6                  Charizard    Fire  Flying           1    534  78
# 7      6  CharizardMega Charizard X    Fire  Dragon           1    634  78
# 8      6  CharizardMega Charizard Y    Fire  Flying           1    634  78
# ..   ...                        ...     ...     ...         ...    ...  ..
# 736  668                     Pyroar    Fire  Normal           6    507  86
# 758  688                    Binacle    Rock   Water           6    306  42
# 759  689                 Barbaracle    Rock   Water           6    500  72
# 760  690                     Skrelp  Poison   Water           6    320  50
# 799  721                  Volcanion    Fire   Water           6    600  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation Legendary
# 4        52       43       60       50     65           1      True
# 5        64       58       80       65     80           1      True
# 6        84       78      109       85    100           1      True
# 7       130      111      130       85    100           1      True
# 8       104       78      159      115    100           1      True
# ..      ...      ...      ...      ...    ...         ...       ...
# 736      68       72      109       66    106           6      True
# 758      52       67       39       56     50           6      True
# 759     105      115       54       86     68           6      True
# 760      60       60       60       60     30           6      True
# 799     110      120      130       90     70           6      True
#
# [65 rows x 14 columns]

# %%
dataframe.loc[(dataframe['Total'] > 500), ['Attack','Defense']] = ['Wet','Status'] # Can alter multiple respectively
dataframe
# Out:
#        #                   Name   Type 1  Type 2 Generation  Total  HP Attack  \
# 0      1              Bulbasaur    Grass  Poison          1    318  45     49
# 1      2                Ivysaur    Grass  Poison          1    405  60     62
# 2      3               Venusaur    Grass  Poison          1    525  80    Wet
# 3      3  VenusaurMega Venusaur    Grass  Poison          1    625  80    Wet
# 4      4             Charmander     Fire     NaN          1    309  39     52
# ..   ...                    ...      ...     ...        ...    ...  ..    ...
# 795  719                Diancie     Rock   Fairy          6    600  50    Wet
# 796  719    DiancieMega Diancie     Rock   Fairy          6    700  50    Wet
# 797  720    HoopaHoopa Confined  Psychic   Ghost          6    600  80    Wet
# 798  720     HoopaHoopa Unbound  Psychic    Dark          6    680  80    Wet
# 799  721              Volcanion     Fire   Water        Wet    600  80    Wet
#
#     Defense  Sp. Atk  Sp. Def  Speed Generation Legendary
# 0        49       65       65     45          1       NaN
# 1        63       80       80     60          1       NaN
# 2    Status      100      100     80          1       NaN
# 3    Status      122      120     80          1       NaN
# 4        43       60       50     65          1      True
# ..      ...      ...      ...    ...        ...       ...
# 795  Status      100      150     50          6       NaN
# 796  Status      160      110    110          6       NaN
# 797  Status      150      130     70          6       NaN
# 798  Status      170      130     80          6       NaN
# 799  Status      130       90     70        Wet       Wet
#
# [800 rows x 14 columns]

# %%
# Reloading or starting to when it was raw

df = pd.read_csv('pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]

# %% [markdown]
# ## Aggregate Statistics (Groupby)
#
# Ex. Getting the average defense of grass type pokemons

# %%
# Getting the average stats of each 'type 1' groups and sorting them in descending order of HP value
df.groupby(['Type 1']).mean(True).sort_values('HP', ascending= False).head(5)
# Out:
#              #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 1
# Fire     721.0  80.0   110.0    120.0    130.0     90.0   70.0         6.0
# Psychic  720.0  80.0   135.0     60.0    160.0    130.0   75.0         6.0
# Rock     719.0  50.0   130.0    130.0    130.0    130.0   80.0         6.0
#
#          Legendary
# Type 1
# Fire           1.0
# Psychic        1.0
# Rock           1.0

# %%
df['count'] = 1

# Can get specific columns and group by multiple parameters
df.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# ## Working with Large Amounts of Data

# %%
# Creates a new empty data frame that inherits the columns of the prev df
fresh_df = pd.DataFrame(columns=df.columns)

# 5 rows will be taken each loop
for df in pd.read_csv('pokemon.csv', chunksize=5):
    results = df.groupby(['Type 1']).count()

    # Concatenates the results and assign it to the new df
    fresh_df = pd.concat([fresh_df, results])

fresh_df
# Out:
#          # Name Type 1 Type 2 HP Attack Defense Sp. Atk Sp. Def Speed  \
# Fire     1    1    NaN      0  1      1       1       1       1     1
# Grass    4    4    NaN      4  4      4       4       4       4     4
# Fire     4    4    NaN      3  4      4       4       4       4     4
# Water    1    1    NaN      0  1      1       1       1       1     1
# Bug      2    2    NaN      0  2      2       2       2       2     2
# ...     ..  ...    ...    ... ..    ...     ...     ...     ...   ...
# Fairy    1    1    NaN      0  1      1       1       1       1     1
# Flying   2    2    NaN      2  2      2       2       2       2     2
# Fire     1    1    NaN      1  1      1       1       1       1     1
# Psychic  2    2    NaN      2  2      2       2       2       2     2
# Rock     2    2    NaN      2  2      2       2       2       2     2
#
#         Generation Legendary
# Fire             1         1
# Grass            4         4
# Fire             4         4
# Water            1         1
# Bug              2         2
# ...            ...       ...
# Fairy            1         1
# Flying           2         2
# Fire             1         1
# Psychic          2         2
# Rock             2         2
#
# [433 rows x 12 columns]
